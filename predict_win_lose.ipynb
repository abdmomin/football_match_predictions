# %%
import pandas as pd

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  14.0  2.0  18.4  0.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN   1.0  0.0  17.0  0.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN   1.0  0.0   7.2  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN   6.0  1.0  10.8  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  10.0  2.0  19.4  0.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1494, 27)

# %% [markdown]
# There are 38 matches and 20 teams each season in an EPL game; We have data for 2 seasons 2021 & 2022.  So the data should have 38x20x2 rows.

# %%
38 * 20 * 2
# Out:
# 1520

# %%
matches.team.value_counts()
# Out:
# Manchester City             75
# Wolverhampton Wanderers     75
# Leeds United                75
# Southampton                 75
# Liverpool                   75
# Brighton and Hove Albion    75
# Newcastle United            75
# West Ham United             75
# Manchester United           75
# Arsenal                     75
# Tottenham Hotspur           75
# Leicester City              74
# Crystal Palace              74
# Aston Villa                 74
# Everton                     74
# Chelsea                     74
# Burnley                     74
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   37
# Watford                     37
# Norwich City                37
# Name: team, dtype: int64

# %%
matches['round'].value_counts()
# Out:
# Matchweek 1     40
# Matchweek 19    40
# Matchweek 21    40
# Matchweek 22    40
# Matchweek 23    40
# Matchweek 24    40
# Matchweek 25    40
# Matchweek 26    40
# Matchweek 28    40
# Matchweek 29    40
# Matchweek 31    40
# Matchweek 32    40
# Matchweek 30    40
# Matchweek 34    40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 2     40
# Matchweek 20    40
# Matchweek 10    40
# Matchweek 16    40
# Matchweek 15    40
# Matchweek 14    40
# Matchweek 13    40
# Matchweek 12    40
# Matchweek 3     40
# Matchweek 11    40
# Matchweek 17    40
# Matchweek 9     40
# Matchweek 8     40
# Matchweek 7     40
# Matchweek 6     40
# Matchweek 5     40
# Matchweek 4     40
# Matchweek 33    38
# Matchweek 18    38
# Matchweek 27    38
# Matchweek 38    20
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches['venue_code'] = matches['venue'].astype('category').cat.codes

# %%
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
matches['hour'] = matches['time'].str.replace(':.+', '', regex=True).astype('int')

# %%
matches['day_code'] = matches['date'].dt.dayofweek

# %%
matches['target'] = (matches['result'] == 'W').astype('int')

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1       Tottenham  ...  0.0  0.0    0.0    2022  Manchester City          0
# 2    Norwich City  ...  0.0  0.0    0.0    2022  Manchester City          1
# 3         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City          1
# 4  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City          0
# 6     Southampton  ...  0.0  0.0    0.0    2022  Manchester City          1
#
#   opp_code hour  day_code  target
# 1       18   16         6       0
# 2       15   15         5       1
# 3        0   12         5       1
# 4       10   15         5       1
# 6       17   15         5       0
#
# [5 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches['date'] < '2022-01-01']

# %%
test = matches[matches['date'] > '2022-01-01']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
pred = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], pred)

# %%
acc
# Out:
# 0.5994475138121547

# %%
combined = pd.DataFrame(dict(actual=test['target'], predictions=pred))

# %%
pd.crosstab(index=combined['actual'], columns=combined['predictions'])
# Out:
# predictions    0   1
# actual
# 0            175  43
# 1            102  42

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test['target'], pred)
# Out:
# 0.49411764705882355

# %% [markdown]
# Improving accuracy of the model

# %%
grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Manchester City')

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W  2.0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L  1.0
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W  4.0
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L  2.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  5.0
#
#      ga        opponent  ...   fk   pk  pkatt  season             team  \
# 1   1.0       Tottenham  ...  0.0  0.0    0.0    2022  Manchester City
# 2   0.0    Norwich City  ...  0.0  0.0    0.0    2022  Manchester City
# 3   0.0         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City
# 4   0.0  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City
# 6   0.0     Southampton  ...  0.0  0.0    0.0    2022  Manchester City
# ..  ...             ...  ...  ...  ...    ...     ...              ...
# 54  0.0  Crystal Palace  ...  0.0  0.0    0.0    2021  Manchester City
# 56  2.0         Chelsea  ...  1.0  0.0    0.0    2021  Manchester City
# 57  3.0   Newcastle Utd  ...  1.0  1.0    2.0    2021  Manchester City
# 58  3.0        Brighton  ...  1.0  0.0    0.0    2021  Manchester City
# 59  0.0         Everton  ...  0.0  0.0    1.0    2021  Manchester City
#
#    venue_code opp_code hour  day_code  target
# 1           0       18   16         6       0
# 2           1       15   15         5       1
# 3           1        0   12         5       1
# 4           0       10   15         5       1
# 6           1       17   15         5       0
# ..        ...      ...  ...       ...     ...
# 54          0        6   12         5       1
# 56          1        5   17         5       0
# 57          0       14   20         4       1
# 58          0        3   19         1       0
# 59          1        7   16         6       1
#
# [75 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    group[new_cols] = group[cols].rolling(3, closed='left').mean()
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_rolling' for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 36 2022-04-24  14:00  Premier League  Matchweek 34
#                         37 2022-04-30  15:00  Premier League  Matchweek 35
#                         38 2022-05-07  15:00  Premier League  Matchweek 36
#                         39 2022-05-11  20:15  Premier League  Matchweek 33
#                         40 2022-05-15  14:00  Premier League  Matchweek 37
#
#                             day venue result   gf   ga         opponent  ...  \
# team                                                                     ...
# Arsenal                 6   Sun  Home      W  2.0  1.0    Sheffield Utd  ...
#                         7   Sat  Away      L  0.0  1.0  Manchester City  ...
#                         9   Sun  Home      L  0.0  1.0   Leicester City  ...
#                         11  Sun  Away      W  1.0  0.0   Manchester Utd  ...
#                         13  Sun  Home      L  0.0  3.0      Aston Villa  ...
# ...                         ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 36  Sun  Away      L  0.0  1.0          Burnley  ...
#                         37  Sat  Home      L  0.0  3.0         Brighton  ...
#                         38  Sat  Away      D  2.0  2.0          Chelsea  ...
#                         39  Wed  Home      L  1.0  5.0  Manchester City  ...
#                         40  Sun  Home      D  1.0  1.0     Norwich City  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 6          6       1    2.000000    1.333333
#                         7          5       0    1.666667    1.666667
#                         9          6       0    1.000000    1.666667
#                         11         6       1    0.666667    1.000000
#                         13         6       0    0.333333    0.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 36         6       0    1.333333    1.666667
#                         37         5       0    0.666667    1.000000
#                         38         5       0    0.000000    1.666667
#                         39         2       0    0.666667    2.000000
#                         40         6       0    1.000000    3.333333
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 6   13.666667    4.666667    20.066667   0.000000
#                         7   14.000000    4.666667    19.433333   0.000000
#                         9   13.333333    5.333333    19.233333   0.000000
#                         11   8.333333    3.333333    23.700000   0.333333
#                         13   9.333333    3.333333    21.833333   0.333333
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 36  13.333333    4.000000    17.300000   1.000000
#                         37  12.666667    4.000000    19.133333   0.666667
#                         38  13.000000    5.333333    19.533333   0.333333
#                         39  15.666667    6.000000    18.800000   0.666667
#                         40  16.333333    6.000000    17.166667   0.666667
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 6     0.000000       0.000000
#                         7     0.000000       0.000000
#                         9     0.000000       0.000000
#                         11    0.000000       0.000000
#                         13    0.000000       0.000000
# ...                                ...            ...
# Wolverhampton Wanderers 36    0.666667       0.666667
#                         37    0.666667       0.666667
#                         38    0.666667       1.000000
#                         39    0.666667       1.000000
#                         40    0.666667       1.000000
#
# [1422 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 6  2020-10-04  14:00  Premier League  Matchweek 4  Sun  Home      W  2.0  1.0
# 7  2020-10-17  17:30  Premier League  Matchweek 5  Sat  Away      L  0.0  1.0
# 9  2020-10-25  19:15  Premier League  Matchweek 6  Sun  Home      L  0.0  1.0
# 11 2020-11-01  16:30  Premier League  Matchweek 7  Sun  Away      W  1.0  0.0
# 13 2020-11-08  19:15  Premier League  Matchweek 8  Sun  Home      L  0.0  3.0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 6     Sheffield Utd  ...         6       1    2.000000    1.333333  13.666667
# 7   Manchester City  ...         5       0    1.666667    1.666667  14.000000
# 9    Leicester City  ...         6       0    1.000000    1.666667  13.333333
# 11   Manchester Utd  ...         6       1    0.666667    1.000000   8.333333
# 13      Aston Villa  ...         6       0    0.333333    0.666667   9.333333
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 6     4.666667    20.066667   0.000000         0.0            0.0
# 7     4.666667    19.433333   0.000000         0.0            0.0
# 9     5.333333    19.233333   0.000000         0.0            0.0
# 11    3.333333    23.700000   0.333333         0.0            0.0
# 13    3.333333    21.833333   0.333333         0.0            0.0
#
# [5 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2020-10-04  14:00  Premier League  Matchweek 4  Sun  Home      W  2.0  1.0
# 1 2020-10-17  17:30  Premier League  Matchweek 5  Sat  Away      L  0.0  1.0
# 2 2020-10-25  19:15  Premier League  Matchweek 6  Sun  Home      L  0.0  1.0
# 3 2020-11-01  16:30  Premier League  Matchweek 7  Sun  Away      W  1.0  0.0
# 4 2020-11-08  19:15  Premier League  Matchweek 8  Sun  Home      L  0.0  3.0
#
#           opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 0    Sheffield Utd  ...         6       1    2.000000    1.333333  13.666667
# 1  Manchester City  ...         5       0    1.666667    1.666667  14.000000
# 2   Leicester City  ...         6       0    1.000000    1.666667  13.333333
# 3   Manchester Utd  ...         6       1    0.666667    1.000000   8.333333
# 4      Aston Villa  ...         6       0    0.333333    0.666667   9.333333
#
#   sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0    4.666667    20.066667   0.000000         0.0            0.0
# 1    4.666667    19.433333   0.000000         0.0            0.0
# 2    5.333333    19.233333   0.000000         0.0            0.0
# 3    3.333333    23.700000   0.333333         0.0            0.0
# 4    3.333333    21.833333   0.333333         0.0            0.0
#
# [5 rows x 40 columns]

# %%
def make_prediction(data, predictors):
    train = data[data['date'] < '2022-01-01']
    test = data[data['date'] > '2022-01-01']
    rf.fit(train[predictors], train['target'])
    pred = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'], predictions=pred), index=test.index)
    precision = precision_score(test['target'], pred)
    return combined, precision

# %%
combined, precision = make_prediction(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5540540540540541

# %%
combined
# Out:
#       actual  predictions
# 55         0            1
# 56         1            1
# 57         1            0
# 58         1            0
# 59         1            0
# ...      ...          ...
# 1417       0            0
# 1418       0            0
# 1419       0            0
# 1420       0            0
# 1421       0            0
#
# [362 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predictions       date                     team  \
# 55         0            1 2022-01-23                  Arsenal
# 56         1            1 2022-02-10                  Arsenal
# 57         1            0 2022-02-19                  Arsenal
# 58         1            0 2022-02-24                  Arsenal
# 59         1            0 2022-03-06                  Arsenal
# ...      ...          ...        ...                      ...
# 1417       0            0 2022-04-24  Wolverhampton Wanderers
# 1418       0            0 2022-04-30  Wolverhampton Wanderers
# 1419       0            0 2022-05-07  Wolverhampton Wanderers
# 1420       0            0 2022-05-11  Wolverhampton Wanderers
# 1421       0            0 2022-05-15  Wolverhampton Wanderers
#
#              opponent result
# 55            Burnley      D
# 56             Wolves      W
# 57          Brentford      W
# 58             Wolves      W
# 59            Watford      W
# ...               ...    ...
# 1417          Burnley      L
# 1418         Brighton      L
# 1419          Chelsea      D
# 1420  Manchester City      L
# 1421     Norwich City      D
#
# [362 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

# %%
map_values = {
    'Brighton and Hove Albion': 'Brighton',
    'Manchester United': 'Manchester Utd',
    'Newcastle United': 'Newcastle Utd',
    'Tottenham Hotspur': 'Tottenham',
    'West Ham United': 'West Ham',
    'Wolverhampton Wanderers': 'Wolves'
}

# %%
mapping = MissingDict(**map_values)

# %%
mapping['Brighton and Hove Albion']
# Out:
# 'Brighton'

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
combined
# Out:
#       actual  predictions       date                     team  \
# 55         0            1 2022-01-23                  Arsenal
# 56         1            1 2022-02-10                  Arsenal
# 57         1            0 2022-02-19                  Arsenal
# 58         1            0 2022-02-24                  Arsenal
# 59         1            0 2022-03-06                  Arsenal
# ...      ...          ...        ...                      ...
# 1417       0            0 2022-04-24  Wolverhampton Wanderers
# 1418       0            0 2022-04-30  Wolverhampton Wanderers
# 1419       0            0 2022-05-07  Wolverhampton Wanderers
# 1420       0            0 2022-05-11  Wolverhampton Wanderers
# 1421       0            0 2022-05-15  Wolverhampton Wanderers
#
#              opponent result new_team
# 55            Burnley      D  Arsenal
# 56             Wolves      W  Arsenal
# 57          Brentford      W  Arsenal
# 58             Wolves      W  Arsenal
# 59            Watford      W  Arsenal
# ...               ...    ...      ...
# 1417          Burnley      L   Wolves
# 1418         Brighton      L   Wolves
# 1419          Chelsea      D   Wolves
# 1420  Manchester City      L   Wolves
# 1421     Norwich City      D   Wolves
#
# [362 rows x 7 columns]

# %%
marged = combined.merge(combined, left_on=['date', 'new_team'], right_on=['date', 'opponent'])

# %%
marged
# Out:
#      actual_x  predictions_x       date                   team_x  \
# 0           0              1 2022-01-23                  Arsenal
# 1           1              1 2022-02-10                  Arsenal
# 2           1              0 2022-02-19                  Arsenal
# 3           1              0 2022-02-24                  Arsenal
# 4           1              0 2022-03-06                  Arsenal
# ..        ...            ...        ...                      ...
# 357         0              0 2022-04-24  Wolverhampton Wanderers
# 358         0              0 2022-04-30  Wolverhampton Wanderers
# 359         0              0 2022-05-07  Wolverhampton Wanderers
# 360         0              0 2022-05-11  Wolverhampton Wanderers
# 361         0              0 2022-05-15  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predictions_y  \
# 0            Burnley        D    Arsenal         0              0
# 1             Wolves        W    Arsenal         0              0
# 2          Brentford        W    Arsenal         0              0
# 3             Wolves        W    Arsenal         0              0
# 4            Watford        W    Arsenal         0              0
# ..               ...      ...        ...       ...            ...
# 357          Burnley        L     Wolves         1              0
# 358         Brighton        L     Wolves         1              0
# 359          Chelsea        D     Wolves         0              1
# 360  Manchester City        L     Wolves         1              1
# 361     Norwich City        D     Wolves         0              0
#
#                        team_y opponent_y result_y       new_team_y
# 0                     Burnley    Arsenal        D          Burnley
# 1     Wolverhampton Wanderers    Arsenal        L           Wolves
# 2                   Brentford    Arsenal        L        Brentford
# 3     Wolverhampton Wanderers    Arsenal        L           Wolves
# 4                     Watford    Arsenal        L          Watford
# ..                        ...        ...      ...              ...
# 357                   Burnley     Wolves        W          Burnley
# 358  Brighton and Hove Albion     Wolves        W         Brighton
# 359                   Chelsea     Wolves        D          Chelsea
# 360           Manchester City     Wolves        W  Manchester City
# 361              Norwich City     Wolves        D     Norwich City
#
# [362 rows x 13 columns]

# %%
marged[(marged['predictions_x'] == 1) & (marged['predictions_y'] == 0)]['actual_x'].value_counts()
# Out:
# 1    39
# 0    31
# Name: actual_x, dtype: int64

# %%
39 / 70
# Out:
# 0.5571428571428572
